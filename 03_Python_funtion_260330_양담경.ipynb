# %%
# 구구단 출력 함수
gugudan(5)

def gugudan(num):
    print(f'[구구단 {num}단 ]')
    for i in range(1,10):
        print(f'{num} x {i} = {num*i}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 구구단 출력 함수
# ----> 2 gugudan(5)
#       4 def gugudan(num):
#       5     print(f'[구구단 {num}단 ]')
#
# NameError: name 'gugudan' is not defined

# %%
number = int(input('단 입력'))
gugudan(number)
# Out:
# 단 입력 21
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 number = int(input('단 입력'))
# ----> 2 gugudan(number)
#
# NameError: name 'gugudan' is not defined

# %%
for num in range(2,10):
    # num에 해당하는 구구단 출력
    for i in range(1,10):
        print(f'{num} x {i} = {num*i}')
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %%
# 2단부터 9단까지 출력

for i in range(2,10):
    gugudan(i)
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 # 2단부터 9단까지 출력
#       3 for i in range(2,10):
# ----> 4     gugudan(i)
#       5     print()
#
# NameError: name 'gugudan' is not defined

# %%
# return 값 확인

def add_and_mul(a, b):
    return a+b, a*b

result = add_and_mul(3,4)
print(result)

result1, result2 = add_and_mul(3,4)
print(result1, result2)
# Out:
# (7, 12)
# 7 12

# %%
# 지역변수, 전역변수

sum = 10
def test(num):
    global sum
    sum += num

test(5)
print(sum)
# Out:
# 15

# %%
stack = []
capacity = 5

def isFull():
    if len(stack) == capacity:
        return True
    else:
        return False

def push(data):
    if isFull():
        print('Stack이 차 있어서 더 이상 추가할 수가 없습니다.')
    else:
        stack.append(data)

def pop():
    if isEmpty():
        print('Stack이 비어 있습니다')
        return -1
    else:
        return stack.pop()

def isEmpty():
    return len(stack) == 0
    
def peek():
    if isEmpty():
        return -1
    else:
        return stack[-1]

#=======================================================
print(f'[[ 정수형 스택 연산 실습(용량 : {capacity})]]')
print("=================================================")
print(" 1. Push      2. Pop      3. Peek       0. Exit ")
print("=================================================")

while True:


    menu = int(input('> 메뉴 선택 : '))
    if menu == 0:
        break
        
    elif menu == 1:
        data = int(input('데이터 입력 : '))
        push(data)
    elif menu == 2:
        data = pop()
        if data == -1:
            print('Stack이 비어 있습니다.')
        else:
            print(f'가져온 데이터: {data}')
            
    elif menu == 3:
        data = peek()
        if data != -1:
            print(f'가져올 데이터: {data}')
   
    print('> 현재 스택 상태', stack )

print('[[ 정수형 스택 연산 실습 종료]]')
# Out:
# [[ 정수형 스택 연산 실습(용량 : 5)]]
# =================================================
#  1. Push      2. Pop      3. Peek       0. Exit
# =================================================
# > 메뉴 선택 :  1
# 데이터 입력 :  10
# > 현재 스택 상태 [10]
# > 메뉴 선택 :  1
# 데이터 입력 :  20
# > 현재 스택 상태 [10, 20]
# > 메뉴 선택 :  1
# 데이터 입력 :  30
# > 현재 스택 상태 [10, 20, 30]
# > 메뉴 선택 :  2
# 가져온 데이터: 30
# > 현재 스택 상태 [10, 20]
# > 메뉴 선택 :  2
# 가져온 데이터: 20
# > 현재 스택 상태 [10]
# > 메뉴 선택 :  3
# 가져올 데이터: 10
# > 현재 스택 상태 [10]
